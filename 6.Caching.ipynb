# %%
from pyspark.sql.functions import * 

# Create first DataFrame
data1 = [
    (1, "Alice"),
    (2, "Bob"),
    (3, "Charlie"),
    (4, "David"),
    (5, "Eva")
]
df1 = spark.createDataFrame(data1, ["id", "name"])

# %%
display(df1)

# %%
df1 = df1.withColumn('Flag',lit('Yes'))

# %%
display(df1)

# %%
from pyspark.storagelevel import StorageLevel

# %%
# Caching is managed automatically on serverless compute
# Explicit persist() is not supported on serverless compute

# %%
df2 = df1.filter(col('id')==1)

# %%
display(df2)

# %%
df2.explain()

# %%
# Unpersist is not supported on serverless compute
# Caching is managed automatically by the platform

# %%
df2.display()
